# %% [markdown]
# ## santoshhulbutti@gmail.com   |   Flip Robo Technologies   |   Project Internship #31

# %% [markdown]
# ## Assignment #2: Web scrapping using Selenium
#
# NOTE : As the questions mentioned in assignments were too long, much descriptive & were having images & steps, I have reframed the questions in jupyter notebook, though the context remains the same in each question.

# %% [markdown]
# ## Importing necessary libraries

# %%
import pandas as pd
import numpy as np

import selenium
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #
# #
# <h2><font color="red"> Q1 : Write a python program to scrape data for “Data Analyst” Job position in “Bangalore” location. scrape first 10 jobs data(job-title, job-location, company_name, experience_required).</font></h2>

# %% [markdown]
# ### 1. Getting the webpage https://www.naukri.com/

# %%
#connecting to google chrome web driver
driver = webdriver.Chrome(r'chromedriver.exe')

# %%
# getting the webpage
driver.get("https://www.naukri.com/")

# %% [markdown]
# ### 2. Entering “Data Analyst” in “Skill, Designations, Companies” field and entering “Bangalore” in “enter the location” field.

# %%
#getting input field 'Skill, Designations, Companies' from web page storing it in a variable
role = driver.find_element(By.CLASS_NAME,"suggestor-input ")

#entering 'Data Analyst' in the input using 'role' variable
role.send_keys("Data Analyst")

# %%
#getting “enter the location” field from web page storing it in a variable
city = driver.find_element(By.XPATH,'/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input')

#entering 'Bangalore' in the input using 'city' variable
city.send_keys("Bangalore")

# %% [markdown]
# ### 3. clicking the search button.

# %%
# locating search buttom from webpage & storing it in a variable 'button'
button = driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[6]")

# clicking the search button.
button.click()

# %% [markdown]
# ### 4. Scraping the data for the first 10 jobs results.

# %%
#creating empty list to store the data
job_title_analyst = []
job_location_analyst = []
company_name_analyst = []
experience_required_analyst = []

# %%
# lets use for loop to get first 10 jobs on the result page.

# finding job title & appending value to job_title list
titles = driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in titles[0:10]:
    title = i.text
    job_title_analyst.append(title)
    
    
# finding location & appending value to job_location list
locations = driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in locations[0:10]:
    location = i.text
    job_location_analyst.append(location)
    
    
# finding company name & appending value to company_name list
companies = driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in companies[0:10]:
    company = i.text
    company_name_analyst.append(company)
    
    
# finding experience & appending value to company_name list
job_exp = driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi experience"]')
for i in job_exp[0:10]:
    exp = i.text
    experience_required_analyst.append(exp)

# %% [markdown]
# ### 5. Creating dataframe of the scraped data.

# %%
# creating dataframe to store & visualize the data in a tabular format
ANALYST_JOBS = pd.DataFrame(list(zip(job_title_analyst, job_location_analyst, company_name_analyst, experience_required_analyst)),
                              columns =['Job_Title', 'Job_Location', 'Name_of_Company', 'Experience_Required'],
                              index=pd.RangeIndex(start=1, stop=(len(job_title_analyst)+1), name='Sr. No.'))


# Aligning the values of dataframe to the left
ANALYST_JOBS = ANALYST_JOBS.style.set_properties(**{'text-align': 'left'}).set_table_styles([ dict(selector='th',
                                                                                      props=[('text-align', 'left')])])


#showing the Dataframe
ANALYST_JOBS
# Out:
# <style  type="text/css" >
#     #T_eb5630c6_31f9_11ed_8641_900f0ca51e8e th {
#           text-align: left;
# ...

# %% [markdown]
# #
# #
# <h2><font color="red"> Q2: Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location. scrape first 10 jobs data(job-title, job-location, company_name).</font></h2>

# %% [markdown]
# ### 1. Getting the webpage https://www.naukri.com/

# %%
#connecting to google chrome web driver
driver = webdriver.Chrome(r'chromedriver.exe')

# %%
# getting the webpage
driver.get("https://www.naukri.com/")

# %% [markdown]
# ### 2.Entering “Data Scientist” in “Skill, Designations, Companies” field and entering “Bangalore” in “enter the location” field.

# %%
#getting input field 'Skill, Designations, Companies' from web page storing it in a variable
role = driver.find_element(By.CLASS_NAME,"suggestor-input ")

#entering 'Data Scientist' in the input using 'role' variable
role.send_keys("Data Scientist")

# %%
#getting “enter the location” field from web page storing it in a variable
city = driver.find_element(By.XPATH,'/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input')

#entering 'Bangalore' in the input using 'city' variable
city.send_keys("Bangalore")

# %% [markdown]
# ### 3. clicking the search button.

# %%
# locating search buttom from webpage & storing it in a variable 'button'
button = driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[6]")

# clicking the search button.
button.click()

# %% [markdown]
# ### 4. Scraping the data for the first 10 jobs results.

# %%
#creating empty list to store the data
job_title_ds = []
job_location_ds = []
company_name_ds = []

# %%
# lets use for loop to get first 10 jobs on the result page.

# finding job title & appending value to job_title list
titles = driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in titles:
    title = i.text
    job_title_ds.append(title)
    
    
# finding location & appending value to job_location list
locations = driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in locations:
    location = i.text
    job_location_ds.append(location)
    
    
# finding company name & appending value to company_name list
companies = driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in companies:
    company = i.text
    company_name_ds.append(company)

# %% [markdown]
# ### 5. Creating dataframe of the scraped data.

# %%
# creating dataframe to store & visualize the data in a tabular format
DATA_SCIENTIST_JOBS = pd.DataFrame(list(zip(job_title_ds[0:10], job_location_ds[0:10], company_name_ds[0:10])),
                              columns =['Job_Title', 'Job_Location', 'Name_of_Company'],
                              index=pd.RangeIndex(start=1, stop=(len(job_title_ds[0:10])+1), name='Sr. No.'))


# Aligning the values of dataframe to the left
DATA_SCIENTIST_JOBS = DATA_SCIENTIST_JOBS.style.set_properties(**{'text-align': 'left'}).set_table_styles([ dict(selector='th',
                                                                                      props=[('text-align', 'left')])])


#showing the Dataframe
DATA_SCIENTIST_JOBS
# Out:
# <style  type="text/css" >
#     #T_1b494a0c_31fa_11ed_b109_900f0ca51e8e th {
#           text-align: left;
# ...

# %% [markdown]
# #
# #
# <h2><font color="red"> Q3 : In this question you have to scrape data using the filters available on the webpage as shown below:
#
#    1. You have to use the location and salary filter.
#    2. You have to scrape data for “Data Scientist” designation for first 10 job results.
#    3. You have to scrape the job-title, job-location, company name, experience required.
#    4. The location filter to be used is “Delhi/NCR”. The salary filter to be used is “3-6” lakhs.
#     </font></h2>

# %% [markdown]
# ### 1. Getting the webpage https://www.naukri.com/

# %%
#connecting to google chrome web driver
driver = webdriver.Chrome(r'chromedriver.exe')

# %%
# getting the webpage
driver.get("https://www.naukri.com/")

# %% [markdown]
# ### 2. Entering “Data Scientist” in “Skill, Designations, and Companies” field.

# %%
#getting input field 'Skill, Designations, Companies' from web page storing it in a variable
role = driver.find_element(By.CLASS_NAME,"suggestor-input ")

#entering 'Data Scientist' in the input using 'role' variable
role.send_keys("Data Scientist")

# %% [markdown]
# ### 3. clicking the search button.

# %%
# locating search buttom from webpage & storing it in a variable 'button'
button = driver.find_element(By.CLASS_NAME,"qsbSubmit")

# clicking the search button.
button.click()

# %% [markdown]
# ### 4. Applying the location filter and salary filter by checking the respective boxes.

# %%
# applying location “Delhi/NCR” & clicking check box.
location_filt  = driver.find_element(By.XPATH,"/html/body/div[1]/div[4]/div/section[1]/div[2]/div[5]/div[2]/div[3]/label/p/span[1]")
location_filt.click()

# %%
# applying salary “3-6Lakhs” & clicking check box.
salary_filt = driver.find_element(By.XPATH,"/html/body/div[1]/div[4]/div/section[1]/div[2]/div[6]/div[2]/div[2]/label/p/span[1]")
salary_filt.click()

# %% [markdown]
# ### 5. Scraping the data for the first 10 jobs results.

# %%
#creating empty list to store the data
job_title_ds_filt = []
job_location_ds_filt = []
company_name_ds_filt = []
experience_required_ds_filt = []

# %%
# lets use for loop to get first 10 jobs on the result page.

# finding job title & appending value to job_title list
titles = driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in titles:
    title = i.text
    job_title_ds_filt.append(title)
    
    
# finding location & appending value to job_location list
locations = driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in locations:
    location = i.text
    job_location_ds_filt.append(location)
    
    
# finding company name & appending value to company_name list
companies = driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in companies:
    company = i.text
    company_name_ds_filt.append(company)
    
    
# finding experience & appending value to company_name list
job_exp = driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi experience"]')
for i in job_exp:
    exp = i.text
    experience_required_ds_filt.append(exp)

# %% [markdown]
# ### 6. Creating dataframe of the scraped data.

# %%
# creating dataframe to store & visualize the data in a tabular format
DATA_SCIENTIST_FILT_JOBS = pd.DataFrame(list(zip(job_title_ds_filt[0:10], job_location_ds_filt[0:10], company_name_ds_filt[0:10], experience_required_ds_filt[0:10])),
                              columns =['Job_Title', 'Job_Location', 'Name_of_Company', 'Experience_Required'],
                              index=pd.RangeIndex(start=1, stop=(len(job_title_ds_filt[0:10])+1), name='Sr. No.'))


# Aligning the values of dataframe to the left
DATA_SCIENTIST_FILT_JOBS = DATA_SCIENTIST_FILT_JOBS.style.set_properties(**{'text-align': 'left'}).set_table_styles([ dict(selector='th',
                                                                                      props=[('text-align', 'left')])])


#showing the Dataframe
DATA_SCIENTIST_FILT_JOBS
# Out:
# <style  type="text/css" >
#     #T_51862992_31fa_11ed_9521_900f0ca51e8e th {
#           text-align: left;
# ...

# %% [markdown]
# #
# #
# <h2><font color="red"> Q4: Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape following attributes:
#
#    1. Brand
#    2. Product Description
#    3. Price
#    4. Discount
# </font></h2>

# %% [markdown]
# ### 1. Getting the webpage https://www.flipkart.com/

# %%
#connecting to google chrome web driver
driver = webdriver.Chrome(r'chromedriver.exe')

# %%
# getting the webpage
driver.get("https://www.flipkart.com/")

# %%
# closing login popup window
popup_close = driver.find_element(By.XPATH,"/html/body/div[2]/div/div/button")
popup_close.click()

# %% [markdown]
# ### 2. Entering “sunglasses” in the search field and clicking the search icon.

# %%
#getting search input field from web page storing it in a variable
input_field = driver.find_element(By.XPATH,"/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input")

#entering 'sunglasses' in the input using 'input_field' variable
input_field.send_keys("sunglasses")

# locating search button from webpage & storing it in a variable 'button'
button = driver.find_element(By.XPATH,"/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button")

# clicking the search button.
button.click()

# %% [markdown]
# ### 3. scraping the required data.

# %%
# creating empty lists to store data
brand_list = []
product_description_list = []
price_with_discount_list = []
discount_list = []

# %% [markdown]
# ### As a single page has only 40 results we will be using for loop to go to next page of the results for next 40, & repeating till we get details of 100 sunglasses.

# %%
# lets use for loop to scape data within same website but different page numbers.

#dummy variable initialization for page count
first_page = 1 #starting page
last_page = 4 # page number to end scaping


for page in range(first_page,last_page):
    
    #to get brads
    brands = driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in brands:
        brand_list.append(i.text)
    
    #to get product descriptions
    descriptions = driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
    for i in descriptions:
        product_description_list.append(i.text)    
    
    #to get prices with discount
    prices = driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for i in prices:
        price_with_discount_list.append(i.text)
    
    #to get total discount
    discounts = driver.find_elements(By.XPATH,'//div[@class="_3Ay6Sb"]')
    for i in discounts:
        discount_list.append(i.text)
        
    #getting the nextpage button & clicking next    
    next_page = driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_page.click()
    
    time.sleep(5) # to make selenium wait for 5 seconds to load the webpage properly..

# %%
# Gathering only first 100 results & saving the data
brand_list = brand_list[0:100]
product_description_list = product_description_list[0:100]
price_with_discount_list = price_with_discount_list[0:100]
discount_list = discount_list[0:100]

# %% [markdown]
# ### 4. Creating dataframe of the scraped data.

# %%
# creating dataframe to store & visualize the data in a tabular format
SUNGLASSES = pd.DataFrame(list(zip(brand_list, product_description_list, price_with_discount_list, discount_list)),
                              columns =['Brand', 'Description', 'Price_with_Discount', 'Discount'],
                              index=pd.RangeIndex(start=1, stop=(len(brand_list)+1), name='Sr. No.'))


# Aligning the values of dataframe to the left & showing the Dataframe
SUNGLASSES.style.set_properties(**{'text-align': 'left'}).set_table_styles([ dict(selector='th',
                                                                                      props=[('text-align', 'left')])])



# SUNGLASSES
# Out:
# <style  type="text/css" >
#     #T_7dffe9e2_31fa_11ed_9bf3_900f0ca51e8e th {
#           text-align: left;
# ...

# %% [markdown]
# #
# #
# <h2><font color="red"> Q5: Scrape 100 reviews data from flipkart.com for iphone11 phone. You have to scrape following attributes:
#
#    1. Rating
#    2. Review summary
#    3. Full review
#    4. Discount
# </font></h2>

# %% [markdown]
# ### 1. Getting the webpage https://www.flipkart.com/

# %%
#connecting to google chrome web driver
driver = webdriver.Chrome(r'chromedriver.exe')

# %%
# getting the webpage
driver.get("https://www.flipkart.com/")

# %%
# closing login popup window
popup_close = driver.find_element(By.XPATH,"/html/body/div[2]/div/div/button")
popup_close.click()

# %% [markdown]
# ### 2. Entering iphone 11 in Search field, clicking the search button & selecting first result that appears in search results.

# %%
#getting search input field from web page storing it in a variable
input_field = driver.find_element(By.XPATH,"/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input")

#entering 'iphone 11' in the input using 'input_field' variable
input_field.send_keys("iphone 11")


# locating search buttom from webpage & storing it in a variable 'button'
button = driver.find_element(By.XPATH,"/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button")

# clicking the search button.
button.click()

# %%
#clicking on first result of the search 
click_first_result = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[2]/div/div/div/a/div[2]')
click_first_result.click()

# %% [markdown]
# ### Moving to next tab, as flipkart opens clicked/selected result in new tab

# %%
# as the result open up in new tab of the browser we need to go that tab.
driver.switch_to.window(driver.window_handles[1])

# %% [markdown]
# ### 3. Clicking on all reviews button..

# %%
#clicking on the all reviews button
all_rev = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[9]/div[6]/div/a/div/span')
all_rev.click()

# %% [markdown]
# ### 4. scraping the required data.

# %%
# crating empty lists to store data
ratings = []
rev_summary = []
full_review = []


# lets use for loop to scape data within same website but different page numbers.

#dummy variable initialization for page count
first_page = 1 #starting page
last_page = 11 # page number to end scaping


for page in range(first_page,last_page):
    
    #to get all the ratings
    all_ratings = driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
    for i in all_ratings:
        ratings.append(i.text)
        
        
    #to get all review summaries    
    all_rev_summary = driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
    for i in all_rev_summary:
        rev_summary.append(i.text)    
    
    
    #to get all full reviews
    all_full_review = driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
    for i in all_full_review:
        full_review.append(i.text.replace("\n", " "))
    
    #getting the nextpage button & clicking next  
    next_page = driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_page.click()
    
    
    time.sleep(5) # to make wait selenium for 5 seconds to load the webpage properly..

# %% [markdown]
# ### 5. Creating dataframe of the scraped data.

# %%
# creating dataframe to store & visualize the data in a tabular format
i_phone_reviews = pd.DataFrame(list(zip(ratings, rev_summary, full_review)),
                              columns =['Ratings', 'Review_Summary', 'Review'],
                              index=pd.RangeIndex(start=1, stop=(len(ratings)+1), name='Sr. No.'))


# Aligning the values of dataframe to the left & showing the Dataframe
i_phone_reviews.style.set_properties(**{'text-align': 'left'}).set_table_styles([ dict(selector='th',
                                                                                      props=[('text-align', 'left')])])
# Out:
# <style  type="text/css" >
#     #T_146e6bca_31fb_11ed_84c0_900f0ca51e8e th {
#           text-align: left;
# ...

# %% [markdown]
# #
# #
# <h2><font color="red"> Q6: Scrape data for first 100 sneakers you find when you visit flipkart.com You have to scrape following attributes:
#
#    1. Brand
#    2. Product Description
#    3. Price
#    4. Discount
# </font></h2>

# %% [markdown]
# ### 1. Getting the webpage https://www.flipkart.com/

# %%
#connecting to google chrome web driver
driver = webdriver.Chrome(r'chromedriver.exe')

# %%
# getting the webpage
driver.get("https://www.flipkart.com/")

# %%
# closing login popup window
popup_close = driver.find_element(By.XPATH,"/html/body/div[2]/div/div/button")
popup_close.click()

# %% [markdown]
# ### 2. Entering “sneakers” in the search field and clicking the search icon.

# %%
#getting search input field from web page storing it in a variable
input_field = driver.find_element(By.XPATH,"/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input")

# Enter “sneakers” in the search field
input_field.send_keys("sneakers")

# locating search buttom from webpage & storing it in a variable 'button'
button = driver.find_element(By.XPATH,"/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button")

# clicking the search button.
button.click()

# %% [markdown]
# ### 3. scraping the required data.
# ### As a single page has only 40 results we will be using for loop to go to next page of the results for next 40, & repeating till we get details of 100 sneakers.

# %%
# creating empty lists to store data
brand_list = []
product_description_list = []
price_with_discount_list = []
discount_list = []

# lets use for loop to scape data within same website but different page numbers.

#dummy variable initialization for page count
first_page = 1 #starting page
last_page = 4 # page number to end scaping


for page in range(first_page,last_page):
    
    #to get brads
    brands = driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in brands:
        brand_list.append(i.text)
        
        
    #to get product descriptions 
    desc = driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
    for i in desc:
        product_description_list.append(i.text)    
    
    
    #to get prices with discount
    prices = driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for i in prices:
        price_with_discount_list.append(i.text)
    
    
    #to get total discount
    discounts = driver.find_elements(By.XPATH,'//div[@class="_3Ay6Sb"]')
    for i in discounts:
        discount_list.append(i.text)
        
    #getting the nextpage button & clicking next   
    next_page = driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_page.click()
    
    time.sleep(5) # to make wait selenium for 5 seconds to load the webpage properly..

# %%
# Gathering only first 100 results & saving the data
brand_list = brand_list[0:100]
product_description_list = product_description_list[0:100]
price_with_discount_list = price_with_discount_list[0:100]
discount_list = discount_list[0:100]

# %% [markdown]
# ### 4. Creating dataframe of the scraped data.

# %%
# creating dataframe to store & visualize the data in a tabular format
SNEAKERS = pd.DataFrame(list(zip(brand_list, product_description_list, price_with_discount_list, discount_list)),
                              columns =['Brand', 'Description', 'Price_with_Discount', 'Discount'],
                              index=pd.RangeIndex(start=1, stop=(len(brand_list)+1), name='Sr. No.'))


# Aligning the values of dataframe to the left & showing the Dataframe
SNEAKERS.style.set_properties(**{'text-align': 'left'}).set_table_styles([ dict(selector='th',
                                                                                      props=[('text-align', 'left')])])
# Out:
# <style  type="text/css" >
#     #T_f69359fa_31de_11ed_845b_900f0ca51e8e th {
#           text-align: left;
# ...

# %% [markdown]
# #
# #
# <h2><font color="red"> Q7: From https://www.myntra.com/shoes, scrape First 100 shoes data you get with applying Price filter and Color filter to “Black”. You have to scrape following attributes:
#
#    1. Brand
#    2. Product Description
#    3. Price
# </font></h2>

# %% [markdown]
# ### 1. Getting the webpage https://www.myntra.com/shoes

# %%
#connecting to google chrome web driver
driver = webdriver.Chrome(r'chromedriver.exe')

# %%
# getting the webpage
driver.get("https://www.myntra.com/shoes")

# %% [markdown]
# ### 2. Setting filters : Set second Price filter & Color filter to “Black”.

# %%
# setting second price filter

#getting price filter section xpath from web page storing it in a variable
price_filt = driver.find_element(By.XPATH,'/html/body/div[2]/div/div[1]/main/div[3]/div[1]/section/div/div[5]/ul/li[2]/label/div')

#clicking check box.
price_filt.click()

# %%
# setting color filter to black

#getting color filter section xpath from web page storing it in a variable
black_col_filt = driver.find_element(By.XPATH,'/html/body/div[2]/div/div[1]/main/div[3]/div[1]/section/div/div[6]/ul/li[1]')

#clicking check box.
black_col_filt.click()

# %% [markdown]
# ### 3. scraping the required data.
# ### As a single page has only 50 results we will be using for loop to go to next page of the results for next 50, to get details of 100 shoes.

# %%
# creating empty lists to store data
brand_list = []
discription_list = []
price_list = []


# lets use for loop to scape data within same website but different page numbers.

#dummy variable initialization for page count
first_page = 1 #starting page
last_page = 3 # page number to end scaping


for page in range(first_page,last_page):
    
    #to get brands
    brands = driver.find_elements(By.XPATH,'//h3[@class="product-brand"]')
    for i in brands:
        brand_list.append(i.text)
     
    
    #to get product description
    desc = driver.find_elements(By.XPATH,'//h4[@class="product-product"]')
    for i in desc:
        discription_list.append(i.text)    
    
    
    #to get prices of each product
    prices = driver.find_elements(By.XPATH,'//div[@class="product-price"]')
    for i in prices:
        price_list.append(i.text.split('.')[1].split('R')[0])
    
    
    #getting the nextpage button & clicking next
    next_page = driver.find_element(By.XPATH,'//li[@class="pagination-next"]')
    next_page.click()
    
    
    time.sleep(5) # to make wait selenium for 5 seconds to load the webpage properly..

# %% [markdown]
# ### 4. Creating dataframe of the scraped data.

# %%
# creating dataframe to store & visualize the data in a tabular format
myntra_shoes = pd.DataFrame(list(zip(brand_list, discription_list, price_list)),
                              columns =['Brands', 'Product Description', 'Price (in Rupees)'],
                              index=pd.RangeIndex(start=1, stop=(len(ratings)+1), name='Sr. No.'))


# Aligning the values of dataframe to the left & showing the Dataframe
myntra_shoes.style.set_properties(**{'text-align': 'left'}).set_table_styles([ dict(selector='th',
                                                                                      props=[('text-align', 'left')])])
# Out:
# <style  type="text/css" >
#     #T_c9fda936_31e2_11ed_8753_900f0ca51e8e th {
#           text-align: left;
# ...

# %% [markdown]
# #
# #
# <h2><font color="red"> Q8: From https://www.amazon.in/, scrape First 10 laptops data you get with applying CPU Type filter to “Intel Core i7”. You have to scrape following attributes:
#
#    1. Title
#    2. Ratings
#    3. Price
# </font></h2>

# %% [markdown]
# ### 1. Getting the webpage https://www.amazon.in/

# %%
#connecting to google chrome web driver
driver = webdriver.Chrome(r'chromedriver.exe')

# %%
# getting the webpage
driver.get('https://www.amazon.in/')

# %% [markdown]
# ### 2. Entering “Laptop” in the search field and clicking the search icon.

# %%
#getting search input field from web page storing it in a variable & using click() on it
input_field = driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input')
input_field.click()

# %%
# Enter “Laptop” in the search field
input_field.send_keys('Laptop')

# locating search buttom from webpage & storing it in a variable 'button'
button = driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div')

# clicking the search button.
button.click()

# %% [markdown]
# ### 3. setting CPU Type filter to “Intel Core i7”..

# %%
#selecting filter option in  CPU Type & choosing Intel Core i7 option
i7_cpu = driver.find_element(By.XPATH,'//*[@id="p_n_feature_thirteen_browse-bin/12598163031"]/span/a/span')
i7_cpu.click()

# %% [markdown]
# ### 4. scraping the required data.

# %%
# creating empty lists to store data
title = []
product_ratings = []
price = []


#to get title of laptop
titles = driver.find_elements(By.XPATH,'//h2[@class="a-size-mini a-spacing-none a-color-base s-line-clamp-2"]')
for i in titles:
    title.append(i.text)


#to get ratings
ratings_box = driver.find_elements_by_xpath('.//div[@class="a-row a-size-small"]/span')

x = 0  #dummy variable for counting
for i in ratings_box:
    if x%2 == 0:
        if ratings_box != []:
            ratings = i.get_attribute('aria-label')[0:12]
            product_ratings.append(ratings)
        else:
            ratings = 0
            product_ratings.append(ratings)    
    x+=1

    
#to get price    
    prices = driver.find_elements(By.XPATH,'//span[@class="a-price"]')
for i in prices:
    price.append(i.text)

# %%
#Saving only first 10 results
title = title[:10]
product_ratings = product_ratings[:10]
price = price[:10]

# %% [markdown]
# ### 5. Creating dataframe of the scraped data.

# %%
# creating dataframe to store & visualize the data in a tabular format
Laptop_prices = pd.DataFrame(list(zip(title, product_ratings, price)),
                              columns = ['Title', 'Ratings', 'Price'],
                              index = pd.RangeIndex(start=1, stop=(len(title[0:10])+1), name='Sr. No.'))


# Aligning the values of dataframe to the left & showing the Dataframe
Laptop_prices.style.set_properties(**{'text-align': 'left'}).set_table_styles([ dict(selector='th',
                                                                                      props=[('text-align', 'left')])])
# Out:
# <style  type="text/css" >
#     #T_b4d74970_31f7_11ed_9a79_900f0ca51e8e th {
#           text-align: left;
# ...

# %% [markdown]
# #
# #
# <h2><font color="red"> Q9: Write a python program to scrape data from https://www.ambitionbox.com/ for first 10 job results for Data Scientist Designation in Noida location. You have to scrape:
#
#    1. company name
#    2. No. of days ago when job was posted
#    3. Rating of the company
# </font></h2>

# %% [markdown]
# ### 1. Getting the webpage https://www.ambitionbox.com/

# %%
#connecting to google chrome web driver
driver = webdriver.Chrome(r'chromedriver.exe')

# %%
#getting the webpage
driver.get('https://www.ambitionbox.com/')

# %%
# closing login popup window
popup_close = driver.find_element(By.XPATH,'/html/body/div/div/div/div[3]/div/div/button/i')
popup_close.click()

# %% [markdown]
# ### 2. clicking on the jobs option

# %%
#Selecting jobs option & clicking on it
jobs = driver.find_element(By.XPATH,'/html/body/div/div/div/div[1]/header/nav/ul/li[5]/a')
jobs.click()

# %% [markdown]
# ### 3. Entering Data Scientist In place of "Search by Designations, Companies, Skills"..

# %%
#getting search input field from web page storing it in a variable
input_field = driver.find_element(By.XPATH,'/html/body/div/div/div/div[2]/div[1]/div[1]/div/div/div/div/span/input')

#clicking it to highlight
input_field.click()

#Entering “Data Scientist” in the search field
input_field.send_keys('Data Scientist')

# %%
# locating search buttom from webpage & storing it in a variable 'button'
button = driver.find_element(By.XPATH,'/html/body/div/div/div/div[2]/div[1]/div[1]/div/div/div/button')

# clicking the search button.
button.click()

# %%
# locating location filter from webpage & storing it in a variable
filter_loc = driver.find_element(By.XPATH,'/html/body/div/div/div/div[2]/div[1]/div[2]/div[1]/div/div/div/div[2]/div[1]')

# clicking on location filter
filter_loc.click()

# %%
#getting search input field from web page storing it in a variable
city = driver.find_element(By.XPATH,'/html/body/div/div/div/div[2]/div[1]/div[2]/div[1]/div/div/div/div[2]/div[2]/div/div[2]/input')

#clicking it to highlight
city.click()

#Entering “Noida” in the search field
city.send_keys('Noida')

# %%
#locating the noida options from the drop down & saving it in a variable
get_city = driver.find_element(By.XPATH,'/html/body/div/div/div/div[2]/div[1]/div[2]/div[1]/div/div/div/div[2]/div[2]/div/div[3]/div[1]/div[1]/div/label')

#clicking the noida option
get_city.click()

# %% [markdown]
# ### 04. Scaping the required data

# %%
# creating empty lists to store data
company_name = []
rating = []
job_posted = []


#to get Company names
companies = driver.find_elements(By.XPATH,'//p[@class="company body-medium"]')
for i in companies:
    company_name.append(i.text)


#to get Company ratings
ratings = driver.find_elements(By.XPATH,'//span[@class="body-small"]')
for i in ratings:
    rating.append(i.text)    

    
#to get days since jobs posted
posted_list = driver.find_elements(By.XPATH,'//span[@class="body-small-l"]')
x = 0
for i in posted_list:
    if x % 2 == 0:
        job_posted.append(i.text)
    x+=1

# %% [markdown]
# ### 5. Creating dataframe of the scraped data.

# %%
# creating dataframe to store & visualize the data in a tabular format
jobs_posted = pd.DataFrame(list(zip(company_name[0:10], rating[0:10], post[0:10])),
                              columns = ['Company', 'Ratings', 'Job Posted'],
                              index = pd.RangeIndex(start=1, stop=(len(company_name[0:10])+1), name='Sr. No.'))


# Aligning the values of dataframe to the left & showing the Dataframe
jobs_posted.style.set_properties(**{'text-align': 'left'}).set_table_styles([ dict(selector='th',
                                                                                      props=[('text-align', 'left')])])
# Out:
# <style  type="text/css" >
#     #T_0cd9f2a8_31fe_11ed_885f_900f0ca51e8e th {
#           text-align: left;
# ...

# %% [markdown]
# #
# #
# <h2><font color="red"> Q10: Write a python program to scrape the salary data from https://www.ambitionbox.com/ for Data Scientist designation. You have to scrape :
#
#    1. Company name
#    2. Number of salaries
#    3. Average salary
#    4. Minsalary
#    5. Max Salary
# </font></h2>

# %% [markdown]
# ### 1. Getting the webpage https://www.ambitionbox.com/

# %%
#connecting to google chrome web driver
driver = webdriver.Chrome(r'chromedriver.exe')

# %%
#getting the webpage
driver.get("https://www.ambitionbox.com/")

# %%
# closing login popup window
popup_close = driver.find_element(By.XPATH,'/html/body/div/div/div/div[3]/div/div/button/i')
popup_close.click()

# %% [markdown]
# ### 2. go to Salaries & click on Browse Salaries..

# %%
# Locating the salaries button & saving it in a variable
salary_button = driver.find_element(By.XPATH,'/html/body/div/div/div/div[1]/header/nav/ul/li[3]')

#Clicking on the salaries button
salary_button.click()

# %%
# Locating the browse salaries button & saving it in a variable
browse_sal = driver.find_element(By.PARTIAL_LINK_TEXT, 'Salaries')

#Clicking on the browse salaries
browse_sal.click()

# %% [markdown]
# ### 3. entering Data Scientist in salary comparison text input field & clicking on the result in list..

# %%
#getting search input field from web page storing it in a variable
input_field = driver.find_element(By.XPATH,'/html/body/div/div/div/main/section[1]/div[2]/div[1]/span/input')

# Entering “Data Scientist” in the search field
input_field.send_keys('Data Scientist')

# %%
#locating the search button & saving it in a variable
button = driver.find_element(By.XPATH,'/html/body/div/div/div/main/section[1]/div[2]/div[1]/span/div/div/div[1]/div/div/p')

#clicking on the search button
button.click()

# %% [markdown]
# ### 04. Scaping the required data

# %%
# creating empty list to store data
companies = []
total_rec = []
min_max = []
min_sal = []
max_sal = []
avg = []
exp = []



#to get company name
company = driver.find_elements(By.XPATH,'//a[@data-v-4c07f399]')
for i in company:
    companies.append(i.text.replace('\nData Scientist Salary'," ").strip()) 
    
    
#to get total salary records
sal_rec = driver.find_elements(By.XPATH,'//span[@class="datapoints"]')
for i in sal_rec:
    total_rec.append(i.text[9:12])
    
    
#to get min-max salary
tot_sal = driver.find_elements(By.XPATH,'//div[@class="salary-values"]')

for i in tot_sal:
    min_max.append(i.text.replace('\n'," to "))

for n in min_max:
    min_sal.append(n.split('to')[0].strip())
    max_sal.append(n.split('to')[1].strip())
    
#to get avg salary
avg_sal = driver.find_elements(By.XPATH,'//p[@class="averageCtc"]')
for i in avg_sal:
    avg.append(i.text)
    
    
#to get experience
expe = driver.find_elements(By.XPATH,'//div[@class="sbold-list-header"]')
for i in expe:
    exp.append(i.text.split('e')[0].strip())

# %% [markdown]
# ### 5. Creating dataframe of the scraped data.

# %%
# creating dataframe to store & visualize the data in a tabular format
Sal_data = pd.DataFrame(list(zip(companies[0:10], total_rec, avg, min_sal, max_sal, exp)),
                              columns = ['Company','Total_Salary_Record', 'Average_Salary', 'Minimum_Salary', 'Maximum_Salary', 'Experience_Required'],
                              index = pd.RangeIndex(start=1, stop=(len(companies[0:10])+1), name='Sr. No.'))


# Aligning the values of dataframe to the left & showing the Dataframe
Sal_data.style.set_properties(**{'text-align': 'left'}).set_table_styles([ dict(selector='th',
                                                                                      props=[('text-align', 'left')])])
# Out:
# <style  type="text/css" >
#     #T_1bf5ca58_3204_11ed_b62e_900f0ca51e8e th {
#           text-align: left;
# ...
